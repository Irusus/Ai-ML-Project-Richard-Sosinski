# %%
#Import all necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# %%
#Open file called combined and drop the first column as its a duplicate
df = pd.read_csv("Combined.csv")
firstColumn = df.columns[0]
df = df.drop([firstColumn], axis=1)
df.head(5)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111259 entries, 0 to 1111258
# Data columns (total 47 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   flow_duration    1111259 non-null  float64
#  1   Header_Length    1111259 non-null  float64
#  2   Protocol Type    1111259 non-null  float64
#  3   Duration         1111259 non-null  float64
#  4   Rate             1111259 non-null  float64
#  5   Srate            1111259 non-null  float64
#  6   Drate            1111259 non-null  float64
#  7   fin_flag_number  1111259 non-null  float64
#  8   syn_flag_number  1111259 non-null  float64
#  9   rst_flag_number  1111259 non-null  float64
#  10  psh_flag_number  1111259 non-null  float64
#  11  ack_flag_number  1111259 non-null  float64
#  12  ece_flag_number  1111259 non-null  float64
#  13  cwr_flag_number  1111259 non-null  float64
#  14  ack_count        1111259 non-null  float64
#  15  syn_count        1111259 non-null  float64
#  16  fin_count        1111259 non-null  float64
#  17  urg_count        1111259 non-null  float64
#  18  rst_count        1111259 non-null  float64
#  19  HTTP             1111259 non-null  float64
#  20  HTTPS            1111259 non-null  float64
#  21  DNS              1111259 non-null  float64
#  22  Telnet           1111259 non-null  float64
#  23  SMTP             1111259 non-null  float64
#  24  SSH              1111259 non-null  float64
#  25  IRC              1111259 non-null  float64
#  26  TCP              1111259 non-null  float64
#  27  UDP              1111259 non-null  float64
#  28  DHCP             1111259 non-null  float64
#  29  ARP              1111259 non-null  float64
#  30  ICMP             1111259 non-null  float64
#  31  IPv              1111259 non-null  float64
#  32  LLC              1111259 non-null  float64
#  33  Tot sum          1111259 non-null  float64
#  34  Min              1111259 non-null  float64
#  35  Max              1111259 non-null  float64
#  36  AVG              1111259 non-null  float64
#  37  Std              1111259 non-null  float64
#  38  Tot size         1111259 non-null  float64
#  39  IAT              1111259 non-null  float64
#  40  Number           1111259 non-null  float64
#  41  Magnitue         1111259 non-null  float64
#  42  Radius           1111259 non-null  float64
#  43  Covariance       1111259 non-null  float64
#  44  Variance         1111259 non-null  float64
#  45  Weight           1111259 non-null  float64
#  46  label            1111259 non-null  object
# dtypes: float64(46), object(1)
# memory usage: 398.5+ MB

# %%
#Replace Dictionary attack as 1 and beningn as 0 and show the data
df["label"].replace(["DictionaryBruteForce","BenignTraffic"], [1,0], inplace=True)

df.head(5)
df.info()
# Out:
# C:\Users\sosin\AppData\Local\Temp\ipykernel_18868\3872348902.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["label"].replace(["DictionaryBruteForce","BenignTraffic"], [1,0], inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111259 entries, 0 to 1111258
# Data columns (total 47 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   flow_duration    1111259 non-null  float64
#  1   Header_Length    1111259 non-null  float64
#  2   Protocol Type    1111259 non-null  float64
#  3   Duration         1111259 non-null  float64
#  4   Rate             1111259 non-null  float64
#  5   Srate            1111259 non-null  float64
#  6   Drate            1111259 non-null  float64
#  7   fin_flag_number  1111259 non-null  float64
#  8   syn_flag_number  1111259 non-null  float64
#  9   rst_flag_number  1111259 non-null  float64
#  10  psh_flag_number  1111259 non-null  float64
#  11  ack_flag_number  1111259 non-null  float64
#  12  ece_flag_number  1111259 non-null  float64
#  13  cwr_flag_number  1111259 non-null  float64
#  14  ack_count        1111259 non-null  float64
#  15  syn_count        1111259 non-null  float64
#  16  fin_count        1111259 non-null  float64
#  17  urg_count        1111259 non-null  float64
#  18  rst_count        1111259 non-null  float64
#  19  HTTP             1111259 non-null  float64
#  20  HTTPS            1111259 non-null  float64
#  21  DNS              1111259 non-null  float64
#  22  Telnet           1111259 non-null  float64
#  23  SMTP             1111259 non-null  float64
#  24  SSH              1111259 non-null  float64
#  25  IRC              1111259 non-null  float64
#  26  TCP              1111259 non-null  float64
#  27  UDP              1111259 non-null  float64
#  28  DHCP             1111259 non-null  float64
#  29  ARP              1111259 non-null  float64
#  30  ICMP             1111259 non-null  float64
#  31  IPv              1111259 non-null  float64
#  32  LLC              1111259 non-null  float64
#  33  Tot sum          1111259 non-null  float64
#  34  Min              1111259 non-null  float64
#  35  Max              1111259 non-null  float64
#  36  AVG              1111259 non-null  float64
#  37  Std              1111259 non-null  float64
#  38  Tot size         1111259 non-null  float64
#  39  IAT              1111259 non-null  float64
#  40  Number           1111259 non-null  float64
#  41  Magnitue         1111259 non-null  float64
#  42  Radius           1111259 non-null  float64
#  43  Covariance       1111259 non-null  float64
#  44  Variance         1111259 non-null  float64
#  45  Weight           1111259 non-null  float64
#  46  label            1111259 non-null  int64
# dtypes: float64(46), int64(1)
# memory usage: 398.5 MB
# C:\Users\sosin\AppData\Local\Temp\ipykernel_18868\3872348902.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["label"].replace(["DictionaryBruteForce","BenignTraffic"], [1,0], inplace=True)

# %%
#X is the independant variable and Y is the dependant 
X = df.iloc[:,0:46] 
Y = df.iloc[:,-1] 

print(Y)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1111254    1
# 1111255    1
# 1111256    1
# 1111257    1
# 1111258    1
# Name: label, Length: 1111259, dtype: int64

# %%
#This piece of code is used to find the best features and show the score of the features
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

bestFeatures = SelectKBest(score_func=chi2, k=3)
fit = bestFeatures.fit(X,Y)

dfScores = pd.DataFrame(fit.scores_)#
dfColumns = pd.DataFrame(X.columns)

featuresScores = pd.concat([dfColumns, dfScores], axis=1)

featuresScores.columns = ["Features", "Score"]

featuresScores.sort_values(by="Score")
# Out:
#            Features         Score
# 40           Number  2.521993e-03
# 31              IPv  9.898868e-02
# 32              LLC  9.898868e-02
# 30             ICMP  1.189588e-01
# 45           Weight  1.519541e-01
# 9   rst_flag_number  1.794239e-01
# 21              DNS  5.164218e+00
# 29              ARP  2.698145e+01
# 44         Variance  4.568859e+01
# 16        fin_count  1.101825e+02
# 26              TCP  2.299294e+02
# 11  ack_flag_number  3.051668e+02
# 19             HTTP  3.159479e+02
# 2     Protocol Type  4.050706e+02
# 27              UDP  4.569939e+02
# 15        syn_count  5.323760e+02
# 14        ack_count  6.543574e+02
# 8   syn_flag_number  1.031217e+03
# 7   fin_flag_number  1.498764e+03
# 10  psh_flag_number  2.686390e+03
# 20            HTTPS  2.695624e+03
# 41         Magnitue  4.025001e+04
# 3          Duration  5.375362e+04
# 24              SSH  1.600554e+05
# 39              IAT  1.702070e+05
# 17        urg_count  2.988925e+05
# 34              Min  5.433955e+05
# 37              Std  1.871043e+06
# 5             Srate  2.341912e+06
# 4              Rate  2.341912e+06
# 38         Tot size  2.418082e+06
# 36              AVG  2.423822e+06
# 42           Radius  2.642241e+06
# 35              Max  6.969538e+06
# 18        rst_count  1.031006e+07
# 33          Tot sum  2.536280e+07
# 0     flow_duration  1.154858e+08
# 43       Covariance  4.471220e+09
# 1     Header_Length  1.193869e+10
# 6             Drate           NaN
# 12  ece_flag_number           NaN
# 13  cwr_flag_number           NaN
# 22           Telnet           NaN
# 23             SMTP           NaN
# 25              IRC           NaN
# 28             DHCP           NaN

# %%
#Features which were decided to be the best
X = df[["flow_duration", "Header_Length", "Protocol Type", "Duration","Rate" ]]

# %%
#data splitting into train and test for both X and Y with the test size of 20% as is the standard 
X_train, X_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=25)

# %%
#KNN requires for the data to be scaled and this is what this piece of code does
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_val)

# %%
#create the knn model with n being 5
knn_model = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors as needed

# fit the data into the model
knn_model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Create a prediction from the model
y_pred = knn_model.predict(X_test_scaled)

# %%
# get accuracy
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy:", accuracy)

# Additional metrics
print(classification_report(y_val, y_pred))
# Out:
# Accuracy: 0.9888010006659108
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    219593
#            1       0.63      0.16      0.25      2659
#
#     accuracy                           0.99    222252
#    macro avg       0.81      0.58      0.62    222252
# weighted avg       0.99      0.99      0.99    222252

# %%
#get recall value for the model
from sklearn.metrics import recall_score
ensemble_recall = recall_score(y_val, y_pred)

print("Stacking Ensemble Model Recall:", ensemble_recall)
# Out:
# Stacking Ensemble Model Recall: 0.15908236179014668

# %%
#Get f1 score for the model
from sklearn.metrics import f1_score
ensemble_f1_score = f1_score(y_val, y_pred)

print("Stacking Ensemble Model F1 Score:", ensemble_f1_score)
# Out:
# Stacking Ensemble Model F1 Score: 0.2536731634182909
